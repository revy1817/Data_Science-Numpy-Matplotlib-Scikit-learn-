# %% [markdown]
# <a href="https://colab.research.google.com/github/revy1817/Data_Science-Numpy-Matplotlib-Scikit-learn-/blob/less2/Less2_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
DATASET_PATH = '/content/drive/MyDrive/Colab Notebooks/train.csv'
df = pd.read_csv(DATASET_PATH, sep=',')

# %% [markdown]
# # **Задание №1**
#
#
# ---
#
# Построить график распределения целевой переменной. Сделать выводы.

# %%
price = df['Price']

# %%
plt.hist(price, label='Price')
plt.show()

# %% [markdown]
# ## **Вывод:**
#
#
# ---
# Больше всего жилья продается в диапозоне от 100 000 до 250 000

# %% [markdown]
# # **Задание №2**
#
#
#
# ---
#
# Построить столбчатые диаграммы распределений для наиболее проблемных признаков (используйте выводы из первого ДЗ). Сделайте по ним выводы.

# %%
rooms = df['Rooms']

# %%
bins = np.linspace(0, 5)
plt.hist(rooms, bins, log=True)
plt.show()

# %% [markdown]
# # **Вывод:**
# В некоторых квартирах количество комнат равно 0, что не возможно

# %%
square = df["Square"]

# %%
bins = np.linspace(1, 30)
plt.hist(square, bins, log=True)
plt.show()

# %% [markdown]
# # **Вывод:**
# В некоторых квартирах квадратура меньше 6 квадратов, что также не возможно

# %% [markdown]
# # **Задание №3**

# %%
plt.matshow(df.corr())
plt.show()
